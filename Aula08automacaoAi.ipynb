# %% [markdown]
# <a href="https://colab.research.google.com/github/coimbrac137/engenha_de_prompt_aplicacoes_ia/blob/main/Aula08automacaoAi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Automação com AI
#
# Nome: Vinicius Coimbra da Silva

# %% [markdown]
# #Temperatura
# ![WhatsApp Image 2026-04-17 at 21.27.22.jpeg](data:image/jpeg;base64,...)

# %%
# Função que verifica a temperatura recebida como parâmetro
def verificar_temperatura(temp):

    # Verifica se a temperatura é maior que 30 graus
    if temp > 30:
        # Caso seja maior, exibe mensagem de alerta de superaquecimento
        print("ALERTA: Superaquecimento! Temperatura:", temp, "°C")
    else:
        # Caso contrário, informa que a temperatura está normal
        print("Temperatura normal:", temp, "°C")

# Solicita ao usuário que digite uma temperatura
temperatura = float(input("Digite a temperatura: "))

# Chama a função passando a temperatura informada
verificar_temperatura(temperatura)
# Out:
# Digite a temperatura: 68
# ALERTA: Superaquecimento! Temperatura: 68.0 °C

# %% [markdown]
# #Automação de Arquivos
# ![WhatsApp Image 2026-04-17 at 21.39.24.jpeg](data:image/jpeg;base64,...)

# %%
import os
import shutil

# Define a pasta onde os arquivos serão criados e organizados
pasta = "arquivos_teste"

# Cria a pasta caso ela ainda não exista (evita erro)
os.makedirs(pasta, exist_ok=True)

# Lista de extensões que vamos usar para criar os arquivos
extensoes = [".pdf", ".jpg", ".xls", ".doc", ".py", ".ipynb"]

# ================================
# CRIAÇÃO DOS ARQUIVOS DE TESTE
# ================================

# Para cada extensão da lista...
for ext in extensoes:
    # Cria 10 arquivos com aquela extensão
    for i in range(10):
        # Monta o nome do arquivo (ex: arquivo_0.pdf)
        with open(f"{pasta}/arquivo_{i}{ext}", "w") as f:
            # Escreve um conteúdo simples dentro do arquivo
            f.write("teste")

print("Arquivos criados.\n")

# ================================
# ORGANIZAÇÃO DOS ARQUIVOS
# ================================

# Percorre todos os itens dentro da pasta
for arquivo in os.listdir(pasta):
    caminho = f"{pasta}/{arquivo}"  # caminho completo do arquivo

    # Verifica se é realmente um arquivo (e não uma pasta)
    if os.path.isfile(caminho):

        # Pega a extensão do arquivo (ex: pdf, jpg...)
        ext = arquivo.split(".")[-1]

        # Define a pasta de destino com base na extensão
        pasta_destino = f"{pasta}/{ext}"

        # Cria a pasta de destino se ainda não existir
        os.makedirs(pasta_destino, exist_ok=True)

        # Move o arquivo para a pasta correspondente
        shutil.move(caminho, f"{pasta_destino}/{arquivo}")

        # Mostra no terminal o que está acontecendo
        print(f"{arquivo} -> movido para pasta '{ext}'")

print("\nOrganização finalizada!")
# Out:
# Arquivos criados.
#
# arquivo_1.doc -> movido para pasta 'doc'
# arquivo_5.xls -> movido para pasta 'xls'
# arquivo_6.doc -> movido para pasta 'doc'
# arquivo_5.doc -> movido para pasta 'doc'
# arquivo_8.jpg -> movido para pasta 'jpg'
# arquivo_9.xls -> movido para pasta 'xls'
# arquivo_7.jpg -> movido para pasta 'jpg'
# arquivo_6.py -> movido para pasta 'py'
# arquivo_4.pdf -> movido para pasta 'pdf'
# arquivo_1.py -> movido para pasta 'py'
# arquivo_9.py -> movido para pasta 'py'
# arquivo_9.ipynb -> movido para pasta 'ipynb'
# arquivo_6.xls -> movido para pasta 'xls'
# arquivo_7.ipynb -> movido para pasta 'ipynb'
# arquivo_2.py -> movido para pasta 'py'
# arquivo_0.jpg -> movido para pasta 'jpg'
# arquivo_8.doc -> movido para pasta 'doc'
# arquivo_0.py -> movido para pasta 'py'
# arquivo_2.jpg -> movido para pasta 'jpg'
# arquivo_1.ipynb -> movido para pasta 'ipynb'
# arquivo_9.doc -> movido para pasta 'doc'
# arquivo_2.doc -> movido para pasta 'doc'
# arquivo_4.ipynb -> movido para pasta 'ipynb'
# arquivo_2.xls -> movido para pasta 'xls'
# arquivo_6.pdf -> movido para pasta 'pdf'
# arquivo_2.ipynb -> movido para pasta 'ipynb'
# arquivo_0.ipynb -> movido para pasta 'ipynb'
# arquivo_5.py -> movido para pasta 'py'
# arquivo_4.doc -> movido para pasta 'doc'
# arquivo_5.pdf -> movido para pasta 'pdf'
# arquivo_8.pdf -> movido para pasta 'pdf'
# arquivo_6.jpg -> movido para pasta 'jpg'
# arquivo_7.pdf -> movido para pasta 'pdf'
# arquivo_8.xls -> movido para pasta 'xls'
# arquivo_4.xls -> movido para pasta 'xls'
# arquivo_3.jpg -> movido para pasta 'jpg'
# arquivo_3.ipynb -> movido para pasta 'ipynb'
# arquivo_3.pdf -> movido para pasta 'pdf'
# arquivo_5.ipynb -> movido para pasta 'ipynb'
# arquivo_6.ipynb -> movido para pasta 'ipynb'
# arquivo_7.doc -> movido para pasta 'doc'
# arquivo_1.jpg -> movido para pasta 'jpg'
# arquivo_8.py -> movido para pasta 'py'
# arquivo_0.xls -> movido para pasta 'xls'
# arquivo_3.doc -> movido para pasta 'doc'
# arquivo_3.py -> movido para pasta 'py'
# arquivo_7.py -> movido para pasta 'py'
# arquivo_4.jpg -> movido para pasta 'jpg'
# arquivo_1.xls -> movido para pasta 'xls'
# arquivo_9.pdf -> movido para pasta 'pdf'
# arquivo_0.doc -> movido para pasta 'doc'
# arquivo_8.ipynb -> movido para pasta 'ipynb'
# arquivo_9.jpg -> movido para pasta 'jpg'
# arquivo_3.xls -> movido para pasta 'xls'
# arquivo_0.pdf -> movido para pasta 'pdf'
# arquivo_1.pdf -> movido para pasta 'pdf'
# arquivo_2.pdf -> movido para pasta 'pdf'
# arquivo_4.py -> movido para pasta 'py'
# arquivo_7.xls -> movido para pasta 'xls'
# arquivo_5.jpg -> movido para pasta 'jpg'
#
# Organização finalizada!

# %% [markdown]
# #Consulta de CEP![cep (1).png](data:image/png;base64,...)

# %%
import requests  # biblioteca para fazer requisições na internet

# ================================
# ENTRADA DO USUÁRIO
# ================================

# Pede o CEP para o usuário
cep = input("Digite o CEP: ")

# ================================
# CONSULTA NA API
# ================================

# Monta a URL da API do ViaCEP
url = f"https://viacep.com.br/ws/{cep}/json/"

try:
    # Faz a requisição para a API
    resposta = requests.get(url)

    # Converte a resposta para formato JSON (dicionário)
    dados = resposta.json()

    # ================================
    # TRATAMENTO DE ERRO (CEP INVÁLIDO)
    # ================================

    if "erro" in dados:
        print("CEP inválido!")

    else:
        # ================================
        # EXIBIÇÃO FORMATADA
        # ================================

        print("\nEndereço encontrado:")
        print("Rua:", dados["logradouro"])
        print("Bairro:", dados["bairro"])
        print("Cidade:", dados["localidade"])
        print("Estado:", dados["uf"])

except:
    # Caso aconteça erro de conexão ou outro problema
    print("Erro ao conectar com a API.")
# Out:
# Digite o CEP: 70210000
#
# Endereço encontrado:
# Rua: Vila da Telebrasília
# Bairro: Vila da Telebrasília
# Cidade: Brasília
# Estado: DF
